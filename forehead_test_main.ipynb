# %% [markdown]
# <a href="https://colab.research.google.com/github/bidulgiya999/swin_transformer_forehead/blob/main/forehead_test_main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 기존 resnet_custom(stride =1, 전이학습 = True)
# main2.py파일에서 adam 함수 그대로 사용

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !wandb sweep --project swin_trans_forehead /content/drive/MyDrive/swin_transformer/forehead_wrinkle_tool/sweeps2.yaml
# Out:
# wandb: Creating sweep from: /content/drive/MyDrive/swin_transformer/forehead_wrinkle_tool/sweeps2.yaml
# wandb: Creating sweep with ID: mhq0jbz1
# wandb: View sweep at: https://wandb.ai/tpospectre-none/swin_trans_forehead/sweeps/mhq0jbz1
# wandb: Run sweep agent with: wandb agent tpospectre-none/swin_trans_forehead/mhq0jbz1

# %%
# !wandb agent tpospectre-none/swin_trans_forehead/mhq0jbz1
# Out:
# wandb: Starting wandb agent 🕵️
# 2025-12-11 08:28:39,989 - wandb.wandb_agent - INFO - Running runs: []
# 2025-12-11 08:28:40,423 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-12-11 08:28:40,423 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	beta: 0.99
# 	dropout_prob: 0.5
# 	gamma: 3
# 	lr: 1.9176741699711303e-05
# 	weight_decay: 0.000935446036083618
# 2025-12-11 08:28:40,424 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python /content/drive/MyDrive/swin_transformer/forehead_wrinkle_tool/main2.py --output_dir /content/drive/MyDrive/swin_transformer/forehead_wrinkle_tool/result/forehead_result --wandb_dir /content/drive/MyDrive/swin_transformer/forehead_wrinkle_tool/result_wandb/forehead_wandb_result --data_dirs /content/drive/MyDrive/skin_check_ai/dataset/wrinkle/forehead_wrinkle --train_loss cb --beta=0.99 --dropout_prob=0.5 --gamma=3 --lr=1.9176741699711303e-05 --weight_decay=0.000935446036083618
# ...
